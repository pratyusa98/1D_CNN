# %%
import tensorflow as tf
from tensorflow import keras

from tensorflow.keras.models import Sequential,Model,load_model
from tensorflow.keras.layers import Dense, Flatten, Conv1D, MaxPooling1D,AveragePooling1D,MaxPool1D,Input,ZeroPadding1D, Activation,BatchNormalization,Add
from keras.initializers import glorot_uniform
from keras.layers.merge import concatenate

# %% [markdown]
# ### 1D CNN

# %%
model = keras.Sequential([
    keras.layers.Conv1D(filters=96, kernel_size=11, strides=4, activation='relu',input_shape=(64,1)),
    keras.layers.MaxPooling1D(pool_size=3, strides=2),
    
    keras.layers.Conv1D(64, 3, activation='relu'),
    keras.layers.MaxPool1D(),
    
    keras.layers.Flatten(),
    keras.layers.Dense(128, activation='relu'),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(3, activation='softmax')
])

# model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model._name = "Lenet-5"
model.summary()
# Out:
# Model: "Lenet-5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_7 (Conv1D)           (None, 14, 96)            1152
#
#  max_pooling1d_6 (MaxPooling  (None, 6, 96)            0
#  1D)
#
#  conv1d_8 (Conv1D)           (None, 4, 640)            184960
#
#  max_pooling1d_7 (MaxPooling  (None, 2, 640)           0
#  1D)
#
#  flatten_2 (Flatten)         (None, 1280)              0
#
#  dense_5 (Dense)             (None, 128)               163968
#
#  dropout_3 (Dropout)         (None, 128)               0
#
#  dense_6 (Dense)             (None, 3)                 387
#
# =================================================================
# Total params: 350,467
# Trainable params: 350,467
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## 1D - AlexNet

# %%
# AlexNet model

model = Sequential()
model._name = "Alexnet"

#1st conv
model.add(Conv1D(96, kernel_size=11, strides= 4, padding= 'valid', activation= 'relu', input_shape= (64,1),
                        kernel_initializer= 'he_normal'))
model.add(MaxPooling1D(pool_size=2, strides= 2, padding= 'valid', data_format= None))


#2nd conv
model.add(Conv1D(256, kernel_size=5, strides= 1, padding= 'same', activation= 'relu',
                kernel_initializer= 'he_normal'))
model.add(MaxPooling1D(pool_size=3, strides= 2, padding= 'valid', data_format= None)) 


#3rd conv
model.add(Conv1D(384, kernel_size=3, strides= 1, padding= 'same', activation= 'relu',
                kernel_initializer= 'he_normal'))

#4th conv
model.add(Conv1D(384, kernel_size=3, strides= 1, padding= 'same', activation= 'relu',
                kernel_initializer= 'he_normal'))

#5thconv
model.add(Conv1D(256, kernel_size=3, strides= 1, padding= 'same', activation= 'relu',
                kernel_initializer= 'he_normal'))
model.add(MaxPooling1D(pool_size=3, strides= 2, padding= 'valid', data_format= None))

model.add(Flatten())

model.add(Dense(4096, activation= 'relu'))
model.add(Dense(4096, activation= 'relu'))
model.add(Dense(1000, activation= 'softmax'))

model.summary()
# Out:
# Model: "Alexnet"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_82 (Conv1D)          (None, 14, 96)            1152
#
#  max_pooling1d_45 (MaxPoolin  (None, 7, 96)            0
#  g1D)
#
#  conv1d_83 (Conv1D)          (None, 7, 256)            123136
#
#  max_pooling1d_46 (MaxPoolin  (None, 3, 256)           0
#  g1D)
#
#  conv1d_84 (Conv1D)          (None, 3, 384)            295296
#
#  conv1d_85 (Conv1D)          (None, 3, 384)            442752
#
#  conv1d_86 (Conv1D)          (None, 3, 256)            295168
#
#  max_pooling1d_47 (MaxPoolin  (None, 1, 256)           0
#  g1D)
#
#  flatten_12 (Flatten)        (None, 256)               0
#
#  dense_34 (Dense)            (None, 4096)              1052672
#
#  dense_35 (Dense)            (None, 4096)              16781312
#
#  dense_36 (Dense)            (None, 1000)              4097000
#
# =================================================================
# Total params: 23,088,488
# Trainable params: 23,088,488
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## 1D - VGG16

# %%
model = keras.Sequential([
    keras.layers.Input(shape=(64, 1)),
    keras.layers.Conv1D(64, 3, activation='relu', padding='same'),
    keras.layers.Conv1D(64, 3, activation='relu', padding='same'),
    keras.layers.MaxPool1D(),
    
    keras.layers.Conv1D(128, 3, activation='relu', padding='same'),
    keras.layers.Conv1D(128, 3, activation='relu', padding='same'),
    keras.layers.MaxPool1D(),
    
    keras.layers.Conv1D(256, 3, activation='relu', padding='same'),
    keras.layers.Conv1D(256, 3, activation='relu', padding='same'),
    keras.layers.Conv1D(256, 3, activation='relu', padding='same'),
    keras.layers.MaxPool1D(2,2),
    
    keras.layers.Conv1D(512, 3, activation='relu', padding='same'),
    keras.layers.Conv1D(512, 3, activation='relu', padding='same'),
    keras.layers.Conv1D(512, 3, activation='relu', padding='same'),
    keras.layers.MaxPool1D(2,2),
    
    keras.layers.Conv1D(512, 3, activation='relu', padding='same'),
    keras.layers.Conv1D(512, 3, activation='relu', padding='same'),
    keras.layers.Conv1D(512, 3, activation='relu', padding='same'),
    keras.layers.MaxPool1D(2,2),
    
    keras.layers.Flatten(),
    keras.layers.Dense(4096, activation='relu'),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(4096, activation='relu'),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(1, activation='sigmoid')
])

model.summary()
# Out:
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_73 (Conv1D)          (None, 64, 64)            256
#
#  conv1d_74 (Conv1D)          (None, 64, 64)            12352
#
#  max_pooling1d_32 (MaxPoolin  (None, 32, 64)           0
#  g1D)
#
#  conv1d_75 (Conv1D)          (None, 32, 128)           24704
#
#  conv1d_76 (Conv1D)          (None, 32, 128)           49280
#
#  max_pooling1d_33 (MaxPoolin  (None, 16, 128)          0
#  g1D)
#
#  conv1d_77 (Conv1D)          (None, 16, 256)           98560
#
#  conv1d_78 (Conv1D)          (None, 16, 256)           196864
#
#  conv1d_79 (Conv1D)          (None, 16, 256)           196864
#
#  max_pooling1d_34 (MaxPoolin  (None, 8, 256)           0
#  g1D)
#
#  conv1d_80 (Conv1D)          (None, 8, 512)            393728
#
#  conv1d_81 (Conv1D)          (None, 8, 512)            786944
#
#  conv1d_82 (Conv1D)          (None, 8, 512)            786944
#
#  max_pooling1d_35 (MaxPoolin  (None, 4, 512)           0
#  g1D)
#
#  conv1d_83 (Conv1D)          (None, 4, 512)            786944
#
#  conv1d_84 (Conv1D)          (None, 4, 512)            786944
#
#  conv1d_85 (Conv1D)          (None, 4, 512)            786944
#
#  max_pooling1d_36 (MaxPoolin  (None, 2, 512)           0
#  g1D)
#
#  flatten_8 (Flatten)         (None, 1024)              0
#
#  dense_24 (Dense)            (None, 4096)              4198400
#
#  dropout_16 (Dropout)        (None, 4096)              0
#
#  dense_25 (Dense)            (None, 4096)              16781312
#
#  dropout_17 (Dropout)        (None, 4096)              0
#
#  dense_26 (Dense)            (None, 1)                 4097
#
# =================================================================
# Total params: 25,891,137
# Trainable params: 25,891,137
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## 1D- Resnet50

# %%
def identity_block(X, f, filters):
    
    #retrive filters
    F1, F2, F3 = filters

    X_shortcut = X
   
    #first layer
    X = Conv1D(filters=F1, kernel_size=(1), strides=(1), padding='valid')(X)
    X = BatchNormalization()(X)
    X = Activation('relu')(X)
    
    #2nd layer 3x3 filter by default
    X = Conv1D(filters=F2, kernel_size=(f), strides=(1), padding='same')(X)
    X = BatchNormalization()(X)
    X = Activation('relu')(X)
 
    #3rd layer
    X = Conv1D(filters=F3, kernel_size=(1), strides=(1), padding='valid')(X)
    X = BatchNormalization()(X)
    
    #final step: Add shortcut value to F(X), and pass it through a Relu Function
    X = Add()([X, X_shortcut])# SKIP Connection
    X = Activation('relu')(X)

    return X

# %%
def convolutional_block(X, f, filters,s=2):
   
    #retrive filters
    F1, F2, F3 = filters

    X_shortcut = X
    
    #1st layer
    X = Conv1D(filters=F1, kernel_size=(1), strides=(s), padding='valid')(X)
    X = BatchNormalization()(X)
    X = Activation('relu')(X)
    
    #2nd layer 3x3 filter by default
    X = Conv1D(filters=F2, kernel_size=(f), strides=(1), padding='same')(X)
    X = BatchNormalization()(X)
    X = Activation('relu')(X)

    #3rd layer
    X = Conv1D(filters=F3, kernel_size=(1), strides=(1), padding='valid')(X)
    X = BatchNormalization()(X)

    ## Shourtcut path with Conv block using 1x1 conv laye r ##
    X_shortcut = Conv1D(filters=F3, kernel_size=(1), strides=(s), padding='valid')(X_shortcut)
    X_shortcut = BatchNormalization()(X_shortcut)

    #final step: Add shortcut value to F(X), and pass it through a Relu Function
    X = Add()([X, X_shortcut])
    X = Activation('relu')(X)

    return X

# %%
def ResNet50(input_shape=(64,1)):

    #define input with sahpe input_shape
    X_input = Input(input_shape)

    #zero padding
    X = ZeroPadding1D((3))(X_input)

    # stage 1
    X = Conv1D(64, (7), strides=(2))(X)
    X = BatchNormalization()(X)
    X = Activation('relu')(X)
    X = MaxPooling1D((3), strides=(2))(X)

    #stage 2
    X = convolutional_block(X, f=3, filters=[64, 64,256], s=1)
    X = identity_block(X, 3, [64, 64, 256])
    X = identity_block(X, 3, [64, 64, 256])


    #stage 3
    X = convolutional_block(X, f=3, filters=[128, 128, 512], s=2)
    X = identity_block(X, 3, [128, 128, 512])
    X = identity_block(X, 3, [128, 128, 512])
    X = identity_block(X, 3, [128, 128, 512])

    #stage4 
    X = convolutional_block(X, f=3, filters=[256, 256, 1024], s=2)
    X = identity_block(X, 3, [256, 256, 1024])
    X = identity_block(X, 3, [256, 256, 1024])
    X = identity_block(X, 3, [256, 256, 1024])
    X = identity_block(X, 3, [256, 256, 1024])
    X = identity_block(X, 3, [256, 256, 1024])

    X = X = convolutional_block(X, f=3, filters=[512, 512, 2048], s=2)
    X = identity_block(X, 3, [512, 512, 2048])
    X = identity_block(X, 3, [512, 512, 2048])

    #avgpool
    X = AveragePooling1D(pool_size=(2), padding='same')(X)
    
    X = Flatten()(X)
    X = Dense(2,activation='softmax',kernel_initializer=glorot_uniform(seed=0))(X)
    
    model = Model(inputs=X_input, outputs=X, name='ResNet50')

    return model

model = ResNet50(input_shape=(64,1))

model.summary()
# Out:
# Model: "ResNet50"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_20 (InputLayer)          [(None, 64, 1)]      0           []
#
#  zero_padding1d_1 (ZeroPadding1  (None, 70, 1)       0           ['input_20[0][0]']
#  D)
#
#  conv1d_121 (Conv1D)            (None, 32, 64)       512         ['zero_padding1d_1[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 32, 64)      256         ['conv1d_121[0][0]']
#  rmalization)
#
#  activation (Activation)        (None, 32, 64)       0           ['batch_normalization_1[0][0]']
#
#  max_pooling1d_45 (MaxPooling1D  (None, 15, 64)      0           ['activation[0][0]']
#  )
#
#  conv1d_122 (Conv1D)            (None, 15, 64)       4160        ['max_pooling1d_45[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 15, 64)      256         ['conv1d_122[0][0]']
#  rmalization)
#
#  activation_1 (Activation)      (None, 15, 64)       0           ['batch_normalization_2[0][0]']
#
#  conv1d_123 (Conv1D)            (None, 15, 64)       12352       ['activation_1[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 15, 64)      256         ['conv1d_123[0][0]']
#  rmalization)
#
#  activation_2 (Activation)      (None, 15, 64)       0           ['batch_normalization_3[0][0]']
#
#  conv1d_124 (Conv1D)            (None, 15, 256)      16640       ['activation_2[0][0]']
#
#  conv1d_125 (Conv1D)            (None, 15, 256)      16640       ['max_pooling1d_45[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 15, 256)     1024        ['conv1d_124[0][0]']
#  rmalization)
#
#  batch_normalization_5 (BatchNo  (None, 15, 256)     1024        ['conv1d_125[0][0]']
#  rmalization)
#
#  add_10 (Add)                   (None, 15, 256)      0           ['batch_normalization_4[0][0]',
#                                                                   'batch_normalization_5[0][0]']
#
#  activation_3 (Activation)      (None, 15, 256)      0           ['add_10[0][0]']
#
#  conv1d_126 (Conv1D)            (None, 15, 64)       16448       ['activation_3[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 15, 64)      256         ['conv1d_126[0][0]']
#  rmalization)
#
#  activation_4 (Activation)      (None, 15, 64)       0           ['batch_normalization_6[0][0]']
#
#  conv1d_127 (Conv1D)            (None, 15, 64)       12352       ['activation_4[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 15, 64)      256         ['conv1d_127[0][0]']
#  rmalization)
#
#  activation_5 (Activation)      (None, 15, 64)       0           ['batch_normalization_7[0][0]']
#
#  conv1d_128 (Conv1D)            (None, 15, 256)      16640       ['activation_5[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 15, 256)     1024        ['conv1d_128[0][0]']
#  rmalization)
#
#  add_11 (Add)                   (None, 15, 256)      0           ['batch_normalization_8[0][0]',
#                                                                   'activation_3[0][0]']
#
#  activation_6 (Activation)      (None, 15, 256)      0           ['add_11[0][0]']
#
#  conv1d_129 (Conv1D)            (None, 15, 64)       16448       ['activation_6[0][0]']
#
#  batch_normalization_9 (BatchNo  (None, 15, 64)      256         ['conv1d_129[0][0]']
#  rmalization)
#
#  activation_7 (Activation)      (None, 15, 64)       0           ['batch_normalization_9[0][0]']
#
#  conv1d_130 (Conv1D)            (None, 15, 64)       12352       ['activation_7[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 15, 64)      256         ['conv1d_130[0][0]']
#  ormalization)
#
#  activation_8 (Activation)      (None, 15, 64)       0           ['batch_normalization_10[0][0]']
#
#  conv1d_131 (Conv1D)            (None, 15, 256)      16640       ['activation_8[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 15, 256)     1024        ['conv1d_131[0][0]']
#  ormalization)
#
#  add_12 (Add)                   (None, 15, 256)      0           ['batch_normalization_11[0][0]',
#                                                                   'activation_6[0][0]']
#
#  activation_9 (Activation)      (None, 15, 256)      0           ['add_12[0][0]']
#
#  conv1d_132 (Conv1D)            (None, 8, 128)       32896       ['activation_9[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 8, 128)      512         ['conv1d_132[0][0]']
#  ormalization)
#
#  activation_10 (Activation)     (None, 8, 128)       0           ['batch_normalization_12[0][0]']
#
#  conv1d_133 (Conv1D)            (None, 8, 128)       49280       ['activation_10[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 8, 128)      512         ['conv1d_133[0][0]']
#  ormalization)
#
#  activation_11 (Activation)     (None, 8, 128)       0           ['batch_normalization_13[0][0]']
#
#  conv1d_134 (Conv1D)            (None, 8, 512)       66048       ['activation_11[0][0]']
#
#  conv1d_135 (Conv1D)            (None, 8, 512)       131584      ['activation_9[0][0]']
#
#  batch_normalization_14 (BatchN  (None, 8, 512)      2048        ['conv1d_134[0][0]']
#  ormalization)
#
#  batch_normalization_15 (BatchN  (None, 8, 512)      2048        ['conv1d_135[0][0]']
#  ormalization)
#
#  add_13 (Add)                   (None, 8, 512)       0           ['batch_normalization_14[0][0]',
#                                                                   'batch_normalization_15[0][0]']
#
#  activation_12 (Activation)     (None, 8, 512)       0           ['add_13[0][0]']
#
#  conv1d_136 (Conv1D)            (None, 8, 128)       65664       ['activation_12[0][0]']
#
#  batch_normalization_16 (BatchN  (None, 8, 128)      512         ['conv1d_136[0][0]']
#  ormalization)
#
#  activation_13 (Activation)     (None, 8, 128)       0           ['batch_normalization_16[0][0]']
#
#  conv1d_137 (Conv1D)            (None, 8, 128)       49280       ['activation_13[0][0]']
#
#  batch_normalization_17 (BatchN  (None, 8, 128)      512         ['conv1d_137[0][0]']
#  ormalization)
#
#  activation_14 (Activation)     (None, 8, 128)       0           ['batch_normalization_17[0][0]']
#
#  conv1d_138 (Conv1D)            (None, 8, 512)       66048       ['activation_14[0][0]']
#
#  batch_normalization_18 (BatchN  (None, 8, 512)      2048        ['conv1d_138[0][0]']
#  ormalization)
#
#  add_14 (Add)                   (None, 8, 512)       0           ['batch_normalization_18[0][0]',
#                                                                   'activation_12[0][0]']
#
#  activation_15 (Activation)     (None, 8, 512)       0           ['add_14[0][0]']
#
#  conv1d_139 (Conv1D)            (None, 8, 128)       65664       ['activation_15[0][0]']
#
#  batch_normalization_19 (BatchN  (None, 8, 128)      512         ['conv1d_139[0][0]']
#  ormalization)
#
#  activation_16 (Activation)     (None, 8, 128)       0           ['batch_normalization_19[0][0]']
#
#  conv1d_140 (Conv1D)            (None, 8, 128)       49280       ['activation_16[0][0]']
#
#  batch_normalization_20 (BatchN  (None, 8, 128)      512         ['conv1d_140[0][0]']
#  ormalization)
#
#  activation_17 (Activation)     (None, 8, 128)       0           ['batch_normalization_20[0][0]']
#
#  conv1d_141 (Conv1D)            (None, 8, 512)       66048       ['activation_17[0][0]']
#
#  batch_normalization_21 (BatchN  (None, 8, 512)      2048        ['conv1d_141[0][0]']
#  ormalization)
#
#  add_15 (Add)                   (None, 8, 512)       0           ['batch_normalization_21[0][0]',
#                                                                   'activation_15[0][0]']
#
#  activation_18 (Activation)     (None, 8, 512)       0           ['add_15[0][0]']
#
#  conv1d_142 (Conv1D)            (None, 8, 128)       65664       ['activation_18[0][0]']
#
#  batch_normalization_22 (BatchN  (None, 8, 128)      512         ['conv1d_142[0][0]']
#  ormalization)
#
#  activation_19 (Activation)     (None, 8, 128)       0           ['batch_normalization_22[0][0]']
#
#  conv1d_143 (Conv1D)            (None, 8, 128)       49280       ['activation_19[0][0]']
#
#  batch_normalization_23 (BatchN  (None, 8, 128)      512         ['conv1d_143[0][0]']
#  ormalization)
#
#  activation_20 (Activation)     (None, 8, 128)       0           ['batch_normalization_23[0][0]']
#
#  conv1d_144 (Conv1D)            (None, 8, 512)       66048       ['activation_20[0][0]']
#
#  batch_normalization_24 (BatchN  (None, 8, 512)      2048        ['conv1d_144[0][0]']
#  ormalization)
#
#  add_16 (Add)                   (None, 8, 512)       0           ['batch_normalization_24[0][0]',
#                                                                   'activation_18[0][0]']
#
#  activation_21 (Activation)     (None, 8, 512)       0           ['add_16[0][0]']
#
#  conv1d_145 (Conv1D)            (None, 4, 256)       131328      ['activation_21[0][0]']
#
#  batch_normalization_25 (BatchN  (None, 4, 256)      1024        ['conv1d_145[0][0]']
#  ormalization)
#
#  activation_22 (Activation)     (None, 4, 256)       0           ['batch_normalization_25[0][0]']
#
#  conv1d_146 (Conv1D)            (None, 4, 256)       196864      ['activation_22[0][0]']
#
#  batch_normalization_26 (BatchN  (None, 4, 256)      1024        ['conv1d_146[0][0]']
#  ormalization)
#
#  activation_23 (Activation)     (None, 4, 256)       0           ['batch_normalization_26[0][0]']
#
#  conv1d_147 (Conv1D)            (None, 4, 1024)      263168      ['activation_23[0][0]']
#
#  conv1d_148 (Conv1D)            (None, 4, 1024)      525312      ['activation_21[0][0]']
#
#  batch_normalization_27 (BatchN  (None, 4, 1024)     4096        ['conv1d_147[0][0]']
#  ormalization)
#
#  batch_normalization_28 (BatchN  (None, 4, 1024)     4096        ['conv1d_148[0][0]']
#  ormalization)
#
#  add_17 (Add)                   (None, 4, 1024)      0           ['batch_normalization_27[0][0]',
#                                                                   'batch_normalization_28[0][0]']
#
#  activation_24 (Activation)     (None, 4, 1024)      0           ['add_17[0][0]']
#
#  conv1d_149 (Conv1D)            (None, 4, 256)       262400      ['activation_24[0][0]']
#
#  batch_normalization_29 (BatchN  (None, 4, 256)      1024        ['conv1d_149[0][0]']
#  ormalization)
#
#  activation_25 (Activation)     (None, 4, 256)       0           ['batch_normalization_29[0][0]']
#
#  conv1d_150 (Conv1D)            (None, 4, 256)       196864      ['activation_25[0][0]']
#
#  batch_normalization_30 (BatchN  (None, 4, 256)      1024        ['conv1d_150[0][0]']
#  ormalization)
#
#  activation_26 (Activation)     (None, 4, 256)       0           ['batch_normalization_30[0][0]']
#
#  conv1d_151 (Conv1D)            (None, 4, 1024)      263168      ['activation_26[0][0]']
#
#  batch_normalization_31 (BatchN  (None, 4, 1024)     4096        ['conv1d_151[0][0]']
#  ormalization)
#
#  add_18 (Add)                   (None, 4, 1024)      0           ['batch_normalization_31[0][0]',
#                                                                   'activation_24[0][0]']
#
#  activation_27 (Activation)     (None, 4, 1024)      0           ['add_18[0][0]']
#
#  conv1d_152 (Conv1D)            (None, 4, 256)       262400      ['activation_27[0][0]']
#
#  batch_normalization_32 (BatchN  (None, 4, 256)      1024        ['conv1d_152[0][0]']
#  ormalization)
#
#  activation_28 (Activation)     (None, 4, 256)       0           ['batch_normalization_32[0][0]']
#
#  conv1d_153 (Conv1D)            (None, 4, 256)       196864      ['activation_28[0][0]']
#
#  batch_normalization_33 (BatchN  (None, 4, 256)      1024        ['conv1d_153[0][0]']
#  ormalization)
#
#  activation_29 (Activation)     (None, 4, 256)       0           ['batch_normalization_33[0][0]']
#
#  conv1d_154 (Conv1D)            (None, 4, 1024)      263168      ['activation_29[0][0]']
#
#  batch_normalization_34 (BatchN  (None, 4, 1024)     4096        ['conv1d_154[0][0]']
#  ormalization)
#
#  add_19 (Add)                   (None, 4, 1024)      0           ['batch_normalization_34[0][0]',
#                                                                   'activation_27[0][0]']
#
#  activation_30 (Activation)     (None, 4, 1024)      0           ['add_19[0][0]']
#
#  conv1d_155 (Conv1D)            (None, 4, 256)       262400      ['activation_30[0][0]']
#
#  batch_normalization_35 (BatchN  (None, 4, 256)      1024        ['conv1d_155[0][0]']
#  ormalization)
#
#  activation_31 (Activation)     (None, 4, 256)       0           ['batch_normalization_35[0][0]']
#
#  conv1d_156 (Conv1D)            (None, 4, 256)       196864      ['activation_31[0][0]']
#
#  batch_normalization_36 (BatchN  (None, 4, 256)      1024        ['conv1d_156[0][0]']
#  ormalization)
#
#  activation_32 (Activation)     (None, 4, 256)       0           ['batch_normalization_36[0][0]']
#
#  conv1d_157 (Conv1D)            (None, 4, 1024)      263168      ['activation_32[0][0]']
#
#  batch_normalization_37 (BatchN  (None, 4, 1024)     4096        ['conv1d_157[0][0]']
#  ormalization)
#
#  add_20 (Add)                   (None, 4, 1024)      0           ['batch_normalization_37[0][0]',
#                                                                   'activation_30[0][0]']
#
#  activation_33 (Activation)     (None, 4, 1024)      0           ['add_20[0][0]']
#
#  conv1d_158 (Conv1D)            (None, 4, 256)       262400      ['activation_33[0][0]']
#
#  batch_normalization_38 (BatchN  (None, 4, 256)      1024        ['conv1d_158[0][0]']
#  ormalization)
#
#  activation_34 (Activation)     (None, 4, 256)       0           ['batch_normalization_38[0][0]']
#
#  conv1d_159 (Conv1D)            (None, 4, 256)       196864      ['activation_34[0][0]']
#
#  batch_normalization_39 (BatchN  (None, 4, 256)      1024        ['conv1d_159[0][0]']
#  ormalization)
#
#  activation_35 (Activation)     (None, 4, 256)       0           ['batch_normalization_39[0][0]']
#
#  conv1d_160 (Conv1D)            (None, 4, 1024)      263168      ['activation_35[0][0]']
#
#  batch_normalization_40 (BatchN  (None, 4, 1024)     4096        ['conv1d_160[0][0]']
#  ormalization)
#
#  add_21 (Add)                   (None, 4, 1024)      0           ['batch_normalization_40[0][0]',
#                                                                   'activation_33[0][0]']
#
#  activation_36 (Activation)     (None, 4, 1024)      0           ['add_21[0][0]']
#
#  conv1d_161 (Conv1D)            (None, 4, 256)       262400      ['activation_36[0][0]']
#
#  batch_normalization_41 (BatchN  (None, 4, 256)      1024        ['conv1d_161[0][0]']
#  ormalization)
#
#  activation_37 (Activation)     (None, 4, 256)       0           ['batch_normalization_41[0][0]']
#
#  conv1d_162 (Conv1D)            (None, 4, 256)       196864      ['activation_37[0][0]']
#
#  batch_normalization_42 (BatchN  (None, 4, 256)      1024        ['conv1d_162[0][0]']
#  ormalization)
#
#  activation_38 (Activation)     (None, 4, 256)       0           ['batch_normalization_42[0][0]']
#
#  conv1d_163 (Conv1D)            (None, 4, 1024)      263168      ['activation_38[0][0]']
#
#  batch_normalization_43 (BatchN  (None, 4, 1024)     4096        ['conv1d_163[0][0]']
#  ormalization)
#
#  add_22 (Add)                   (None, 4, 1024)      0           ['batch_normalization_43[0][0]',
#                                                                   'activation_36[0][0]']
#
#  activation_39 (Activation)     (None, 4, 1024)      0           ['add_22[0][0]']
#
#  conv1d_164 (Conv1D)            (None, 2, 512)       524800      ['activation_39[0][0]']
#
#  batch_normalization_44 (BatchN  (None, 2, 512)      2048        ['conv1d_164[0][0]']
#  ormalization)
#
#  activation_40 (Activation)     (None, 2, 512)       0           ['batch_normalization_44[0][0]']
#
#  conv1d_165 (Conv1D)            (None, 2, 512)       786944      ['activation_40[0][0]']
#
#  batch_normalization_45 (BatchN  (None, 2, 512)      2048        ['conv1d_165[0][0]']
#  ormalization)
#
#  activation_41 (Activation)     (None, 2, 512)       0           ['batch_normalization_45[0][0]']
#
#  conv1d_166 (Conv1D)            (None, 2, 2048)      1050624     ['activation_41[0][0]']
#
#  conv1d_167 (Conv1D)            (None, 2, 2048)      2099200     ['activation_39[0][0]']
#
#  batch_normalization_46 (BatchN  (None, 2, 2048)     8192        ['conv1d_166[0][0]']
#  ormalization)
#
#  batch_normalization_47 (BatchN  (None, 2, 2048)     8192        ['conv1d_167[0][0]']
#  ormalization)
#
#  add_23 (Add)                   (None, 2, 2048)      0           ['batch_normalization_46[0][0]',
#                                                                   'batch_normalization_47[0][0]']
#
#  activation_42 (Activation)     (None, 2, 2048)      0           ['add_23[0][0]']
#
#  conv1d_168 (Conv1D)            (None, 2, 512)       1049088     ['activation_42[0][0]']
#
#  batch_normalization_48 (BatchN  (None, 2, 512)      2048        ['conv1d_168[0][0]']
#  ormalization)
#
#  activation_43 (Activation)     (None, 2, 512)       0           ['batch_normalization_48[0][0]']
#
#  conv1d_169 (Conv1D)            (None, 2, 512)       786944      ['activation_43[0][0]']
#
#  batch_normalization_49 (BatchN  (None, 2, 512)      2048        ['conv1d_169[0][0]']
#  ormalization)
#
#  activation_44 (Activation)     (None, 2, 512)       0           ['batch_normalization_49[0][0]']
#
#  conv1d_170 (Conv1D)            (None, 2, 2048)      1050624     ['activation_44[0][0]']
#
#  batch_normalization_50 (BatchN  (None, 2, 2048)     8192        ['conv1d_170[0][0]']
#  ormalization)
#
#  add_24 (Add)                   (None, 2, 2048)      0           ['batch_normalization_50[0][0]',
#                                                                   'activation_42[0][0]']
#
#  activation_45 (Activation)     (None, 2, 2048)      0           ['add_24[0][0]']
#
#  conv1d_171 (Conv1D)            (None, 2, 512)       1049088     ['activation_45[0][0]']
#
#  batch_normalization_51 (BatchN  (None, 2, 512)      2048        ['conv1d_171[0][0]']
#  ormalization)
#
#  activation_46 (Activation)     (None, 2, 512)       0           ['batch_normalization_51[0][0]']
#
#  conv1d_172 (Conv1D)            (None, 2, 512)       786944      ['activation_46[0][0]']
#
#  batch_normalization_52 (BatchN  (None, 2, 512)      2048        ['conv1d_172[0][0]']
#  ormalization)
#
#  activation_47 (Activation)     (None, 2, 512)       0           ['batch_normalization_52[0][0]']
#
#  conv1d_173 (Conv1D)            (None, 2, 2048)      1050624     ['activation_47[0][0]']
#
#  batch_normalization_53 (BatchN  (None, 2, 2048)     8192        ['conv1d_173[0][0]']
#  ormalization)
#
#  add_25 (Add)                   (None, 2, 2048)      0           ['batch_normalization_53[0][0]',
#                                                                   'activation_45[0][0]']
#
#  activation_48 (Activation)     (None, 2, 2048)      0           ['add_25[0][0]']
#
#  average_pooling1d (AveragePool  (None, 1, 2048)     0           ['activation_48[0][0]']
#  ing1D)
#
#  flatten_9 (Flatten)            (None, 2048)         0           ['average_pooling1d[0][0]']
#
#  dense_27 (Dense)               (None, 2)            4098        ['flatten_9[0][0]']
#
# ==================================================================================================
# Total params: 16,038,018
# Trainable params: 15,984,898
# Non-trainable params: 53,120
# __________________________________________________________________________________________________

# %% [markdown]
# ## 1D- Google Net

# %%
def Inception_block(input_layer, f1, f2_conv1, f2_conv3, f3_conv1, f3_conv5, f4): 
  # Input: 
  # - f1: number of filters of the 1x1 convolutional layer in the first path
  # - f2_conv1, f2_conv3 are number of filters corresponding to the 1x1 and 3x3 convolutional layers in the second path
  # - f3_conv1, f3_conv5 are the number of filters corresponding to the 1x1 and 5x5  convolutional layer in the third path
  # - f4: number of filters of the 1x1 convolutional layer in the fourth path

  # 1st path:
  path1 = Conv1D(filters=f1, kernel_size = (1), padding = 'same', activation = 'relu')(input_layer)

  # 2nd path
  path2 = Conv1D(filters = f2_conv1, kernel_size = (1), padding = 'same', activation = 'relu')(input_layer)
  path2 = Conv1D(filters = f2_conv3, kernel_size = (3), padding = 'same', activation = 'relu')(path2)

  # 3rd path
  path3 = Conv1D(filters = f3_conv1, kernel_size = (1), padding = 'same', activation = 'relu')(input_layer)
  path3 = Conv1D(filters = f3_conv5, kernel_size = (5), padding = 'same', activation = 'relu')(path3)

  # 4th path
  path4 = MaxPooling1D((3), strides= (1), padding = 'same')(input_layer)
  path4 = Conv1D(filters = f4, kernel_size = (1), padding = 'same', activation = 'relu')(path4)

  output_layer = concatenate([path1, path2, path3, path4], axis = -1)

  return output_layer

# %%
def GoogLeNet():
  # input layer 
  input_layer = Input(shape = (64,1))

  # convolutional layer: filters = 64, kernel_size = (7,7), strides = 2
  X = Conv1D(filters = 64, kernel_size = (7), strides = 2, padding = 'valid', activation = 'relu')(input_layer)

  # max-pooling layer: pool_size = (3,3), strides = 2
  X = MaxPooling1D(pool_size = (3), strides = 2)(X)

  # convolutional layer: filters = 64, strides = 1
  X = Conv1D(filters = 64, kernel_size = (1), strides = 1, padding = 'same', activation = 'relu')(X)

  # convolutional layer: filters = 192, kernel_size = (3,3)
  X = Conv1D(filters = 192, kernel_size = (3), padding = 'same', activation = 'relu')(X)

  # max-pooling layer: pool_size = (3,3), strides = 2
  X = MaxPooling1D(pool_size= (3), strides = 2)(X)

  # 1st Inception block
  X = Inception_block(X, f1 = 64, f2_conv1 = 96, f2_conv3 = 128, f3_conv1 = 16, f3_conv5 = 32, f4 = 32)

  # 2nd Inception block
  X = Inception_block(X, f1 = 128, f2_conv1 = 128, f2_conv3 = 192, f3_conv1 = 32, f3_conv5 = 96, f4 = 64)

  # max-pooling layer: pool_size = (3,3), strides = 2
  X = MaxPooling1D(pool_size= (3), strides = 2)(X)

  # 3rd Inception block
  X = Inception_block(X, f1 = 192, f2_conv1 = 96, f2_conv3 = 208, f3_conv1 = 16, f3_conv5 = 48, f4 = 64)
  
  X = Flatten()(X)
  
  X = Dense(2,activation='softmax')(X)

    
 
  # model
  model = Model(input_layer, [X], name = 'GoogLeNet')

  return model

GoogLeNet = GoogLeNet()
GoogLeNet.summary()
# Out:
# Model: "GoogLeNet"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_22 (InputLayer)          [(None, 64, 1)]      0           []
#
#  conv1d_181 (Conv1D)            (None, 29, 64)       512         ['input_22[0][0]']
#
#  max_pooling1d_48 (MaxPooling1D  (None, 14, 64)      0           ['conv1d_181[0][0]']
#  )
#
#  conv1d_182 (Conv1D)            (None, 14, 64)       4160        ['max_pooling1d_48[0][0]']
#
#  conv1d_183 (Conv1D)            (None, 14, 192)      37056       ['conv1d_182[0][0]']
#
#  max_pooling1d_49 (MaxPooling1D  (None, 6, 192)      0           ['conv1d_183[0][0]']
#  )
#
#  conv1d_185 (Conv1D)            (None, 6, 96)        18528       ['max_pooling1d_49[0][0]']
#
#  conv1d_187 (Conv1D)            (None, 6, 16)        3088        ['max_pooling1d_49[0][0]']
#
#  max_pooling1d_50 (MaxPooling1D  (None, 6, 192)      0           ['max_pooling1d_49[0][0]']
#  )
#
#  conv1d_184 (Conv1D)            (None, 6, 64)        12352       ['max_pooling1d_49[0][0]']
#
#  conv1d_186 (Conv1D)            (None, 6, 128)       36992       ['conv1d_185[0][0]']
#
#  conv1d_188 (Conv1D)            (None, 6, 32)        2592        ['conv1d_187[0][0]']
#
#  conv1d_189 (Conv1D)            (None, 6, 32)        6176        ['max_pooling1d_50[0][0]']
#
#  concatenate (Concatenate)      (None, 6, 256)       0           ['conv1d_184[0][0]',
#                                                                   'conv1d_186[0][0]',
#                                                                   'conv1d_188[0][0]',
#                                                                   'conv1d_189[0][0]']
#
#  conv1d_191 (Conv1D)            (None, 6, 128)       32896       ['concatenate[0][0]']
#
#  conv1d_193 (Conv1D)            (None, 6, 32)        8224        ['concatenate[0][0]']
#
#  max_pooling1d_51 (MaxPooling1D  (None, 6, 256)      0           ['concatenate[0][0]']
#  )
#
#  conv1d_190 (Conv1D)            (None, 6, 128)       32896       ['concatenate[0][0]']
#
#  conv1d_192 (Conv1D)            (None, 6, 192)       73920       ['conv1d_191[0][0]']
#
#  conv1d_194 (Conv1D)            (None, 6, 96)        15456       ['conv1d_193[0][0]']
#
#  conv1d_195 (Conv1D)            (None, 6, 64)        16448       ['max_pooling1d_51[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 6, 480)       0           ['conv1d_190[0][0]',
#                                                                   'conv1d_192[0][0]',
#                                                                   'conv1d_194[0][0]',
#                                                                   'conv1d_195[0][0]']
#
#  max_pooling1d_52 (MaxPooling1D  (None, 2, 480)      0           ['concatenate_1[0][0]']
#  )
#
#  conv1d_197 (Conv1D)            (None, 2, 96)        46176       ['max_pooling1d_52[0][0]']
#
#  conv1d_199 (Conv1D)            (None, 2, 16)        7696        ['max_pooling1d_52[0][0]']
#
#  max_pooling1d_53 (MaxPooling1D  (None, 2, 480)      0           ['max_pooling1d_52[0][0]']
#  )
#
#  conv1d_196 (Conv1D)            (None, 2, 192)       92352       ['max_pooling1d_52[0][0]']
#
#  conv1d_198 (Conv1D)            (None, 2, 208)       60112       ['conv1d_197[0][0]']
#
#  conv1d_200 (Conv1D)            (None, 2, 48)        3888        ['conv1d_199[0][0]']
#
#  conv1d_201 (Conv1D)            (None, 2, 64)        30784       ['max_pooling1d_53[0][0]']
#
#  concatenate_2 (Concatenate)    (None, 2, 512)       0           ['conv1d_196[0][0]',
#                                                                   'conv1d_198[0][0]',
#                                                                   'conv1d_200[0][0]',
#                                                                   'conv1d_201[0][0]']
#
#  flatten_10 (Flatten)           (None, 1024)         0           ['concatenate_2[0][0]']
#
#  dense_28 (Dense)               (None, 2)            2050        ['flatten_10[0][0]']
#
# ==================================================================================================
# Total params: 544,354
# Trainable params: 544,354
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# ## 1D - Mobilenet

# %%
def depthwise_conv_block(x, filters, activation='relu', strides=1, depth_multiplier=1):
    x = keras.layers.DepthwiseConv1D(3, activation=activation, depth_multiplier=depth_multiplier, strides=strides, padding='same')(x)
    x = keras.layers.Conv1D(filters, 1, activation=activation, padding='same')(x)
    return x

inputs = keras.layers.Input(shape=(64, 1))
x = keras.layers.Conv1D(32, 3, activation='relu', strides=2, padding='same')(inputs)
x = depthwise_conv_block(x, 64, strides=1, depth_multiplier=1)
x = depthwise_conv_block(x, 128, strides=2, depth_multiplier=2)
x = depthwise_conv_block(x, 256, strides=2, depth_multiplier=4)

x = keras.layers.GlobalAveragePooling1D()(x)
x = keras.layers.Dense(1, activation='sigmoid')(x)

model = keras.Model(inputs, x)

model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_23 (InputLayer)       [(None, 64, 1)]           0
#
#  conv1d_212 (Conv1D)         (None, 32, 32)            128
#
#  depthwise_conv1d (Depthwise  (None, 32, 32)           128
#  Conv1D)
#
#  conv1d_213 (Conv1D)         (None, 32, 64)            2112
#
#  depthwise_conv1d_1 (Depthwi  (None, 16, 128)          512
#  seConv1D)
#
#  conv1d_214 (Conv1D)         (None, 16, 128)           16512
#
#  depthwise_conv1d_2 (Depthwi  (None, 8, 512)           2048
#  seConv1D)
#
#  conv1d_215 (Conv1D)         (None, 8, 256)            131328
#
#  global_average_pooling1d (G  (None, 256)              0
#  lobalAveragePooling1D)
#
#  dense_29 (Dense)            (None, 1)                 257
#
# =================================================================
# Total params: 153,025
# Trainable params: 153,025
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## 1D- Mobilenet V2

# %%
def bottleneck_block(x, filters, activation='relu', expansion=6, strides=1):
    channels = filters * expansion
    x = keras.layers.Conv1D(channels, 1, activation=activation, padding='same')(x)
    x = keras.layers.DepthwiseConv1D(3, activation=activation, strides=strides, padding='same')(x)
    x = keras.layers.Conv1D(filters, 1, activation=None, padding='same')(x)
    return x

inputs = keras.layers.Input(shape=(None, 1))
x = keras.layers.Conv1D(32, 3, activation='relu', strides=2, padding='same')(inputs)

x = bottleneck_block(x, 16, strides=1, expansion=1)
x = bottleneck_block(x, 24, strides=2, expansion=6)
x = bottleneck_block(x, 32, strides=2, expansion=6)
x = bottleneck_block(x, 64, strides=2, expansion=6)
x = bottleneck_block(x, 96, strides=1, expansion=6)
x = bottleneck_block(x, 160, strides=2, expansion=6)
x = bottleneck_block(x, 320, strides=1, expansion=6)

x = keras.layers.Conv1D(1280, 1, activation='relu', padding='same')(x)
x = keras.layers.GlobalAveragePooling1D()(x)
x = keras.layers.Dense(1, activation='sigmoid')(x)

model = keras.Model(inputs, x)
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, None, 1)]         0
#
#  conv1d_87 (Conv1D)          (None, None, 32)          128
#
#  conv1d_88 (Conv1D)          (None, None, 16)          528
#
#  depthwise_conv1d (Depthwise  (None, None, 16)         64
#  Conv1D)
#
#  conv1d_89 (Conv1D)          (None, None, 16)          272
#
#  conv1d_90 (Conv1D)          (None, None, 144)         2448
#
#  depthwise_conv1d_1 (Depthwi  (None, None, 144)        576
#  seConv1D)
#
#  conv1d_91 (Conv1D)          (None, None, 24)          3480
#
#  conv1d_92 (Conv1D)          (None, None, 192)         4800
#
#  depthwise_conv1d_2 (Depthwi  (None, None, 192)        768
#  seConv1D)
#
#  conv1d_93 (Conv1D)          (None, None, 32)          6176
#
#  conv1d_94 (Conv1D)          (None, None, 384)         12672
#
#  depthwise_conv1d_3 (Depthwi  (None, None, 384)        1536
#  seConv1D)
#
#  conv1d_95 (Conv1D)          (None, None, 64)          24640
#
#  conv1d_96 (Conv1D)          (None, None, 576)         37440
#
#  depthwise_conv1d_4 (Depthwi  (None, None, 576)        2304
#  seConv1D)
#
#  conv1d_97 (Conv1D)          (None, None, 96)          55392
#
#  conv1d_98 (Conv1D)          (None, None, 960)         93120
#
#  depthwise_conv1d_5 (Depthwi  (None, None, 960)        3840
#  seConv1D)
#
#  conv1d_99 (Conv1D)          (None, None, 160)         153760
#
#  conv1d_100 (Conv1D)         (None, None, 1920)        309120
#
#  depthwise_conv1d_6 (Depthwi  (None, None, 1920)       7680
#  seConv1D)
#
#  conv1d_101 (Conv1D)         (None, None, 320)         614720
#
#  conv1d_102 (Conv1D)         (None, None, 1280)        410880
#
#  global_average_pooling1d (G  (None, 1280)             0
#  lobalAveragePooling1D)
#
#  dense_37 (Dense)            (None, 1)                 1281
#
# =================================================================
# Total params: 1,747,625
# Trainable params: 1,747,625
# Non-trainable params: 0
# _________________________________________________________________
